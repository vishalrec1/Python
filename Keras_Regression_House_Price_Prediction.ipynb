# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalrec1/Python/blob/master/Keras_Regression_House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## House Price Prediction Data Overview
#
# We will be using data from a Kaggle data set:
#
# https://www.kaggle.com/harlfoxem/housesalesprediction
#
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# # Capture Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#We are using Kaggle Dataset for House Data Prediction in Montgomery County in California. The definition of the Features is given above
df = pd.read_csv('/tensorflow-1.15.2/python3.6/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.159700e+04  2.159700e+04  ...   21597.000000   21597.000000
# mean   4.580474e+09  5.402966e+05  ...    1986.620318   12758.283512
# std    2.876736e+09  3.673681e+05  ...     685.230472   27274.441950
# min    1.000102e+06  7.800000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.220000e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21597.0  4.580474e+09  ...  7.308900e+09  9.900000e+09
# price          21597.0  5.402966e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21597.0  3.373200e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21597.0  2.115826e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21597.0  2.080322e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21597.0  1.509941e+04  ...  1.068500e+04  1.651359e+06
# floors         21597.0  1.494096e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21597.0  7.547345e-03  ...  0.000000e+00  1.000000e+00
# view           21597.0  2.342918e-01  ...  0.000000e+00  4.000000e+00
# condition      21597.0  3.409825e+00  ...  4.000000e+00  5.000000e+00
# grade          21597.0  7.657915e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21597.0  1.788597e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
#CHECK IF THERE IS ANY MISSING DATA

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#GETTING DISTRIBUTIONS and CORRELATION OF DATA

# %%
plt.figure(figsize=(20,5))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize = (20,7))
sns.scatterplot(data=df,x='price',y='sqft_living')

# %%
plt.figure(figsize=(20,7))
sns.boxplot(data=df,x='bedrooms',y='price')

# %%
plt.figure(figsize=(20,7))
sns.scatterplot(data=df,x='price',y='long')

# %%
plt.figure(figsize=(20,7))
sns.scatterplot(data=df,x='price',y='lat')

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df,x='long',y='lat',hue='price')

# %%
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.sort_values(by='price',ascending=False,axis=0)
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245   6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910   9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245   9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407   2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446   8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
# ...           ...         ...        ...  ...      ...            ...         ...
# 2139   1623049041    5/8/2014    82500.0  ... -122.296           1572       10570
# 8267   3883800011   11/5/2014    82000.0  ... -122.341           1140       11250
# 16184  3028200080   3/24/2015    81000.0  ... -122.315            860        9000
# 465    8658300340   5/23/2014    80000.0  ... -121.909           1200        7500
# ...

# %%
#REMOVING OUTLIERS (Houses whose Price > 3M or so)

# %%
df1 = df.sort_values(by='price',ascending=False,axis=0,ignore_index=True)

# %%
df1.head()
# Out:
#            id        date      price  ...     long  sqft_living15  sqft_lot15
# 0  6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 1  9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 2  9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 3  2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 4  8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
#
# [5 rows x 21 columns]

# %%
outlier_cleaned_df = df.sort_values(by='price',ascending=False,axis=0,ignore_index=True).loc[216:]

# %%
outlier_cleaned_df.shape
# Out:
# (21381, 21)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=outlier_cleaned_df,x='long',y='lat',hue='price',alpha = 0.5,palette='RdYlGn')

# %%
plt.figure(figsize = (20,6))
sns.scatterplot(data=outlier_cleaned_df,x='grade',y='price')

# %%
plt.figure(figsize = (15,6))
sns.countplot(data=outlier_cleaned_df,x='grade')

# %%
plt.figure(figsize = (20,6))
sns.boxplot(data=outlier_cleaned_df,x='grade',y='price')

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#Since 'id' column is not giving any value in our analysis, we can drop this column

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.drop(labels=['id'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (21597, 20)

# %%
#Now lets analyse Date Column and do some Feature Engineering

# %%
type(df['date'].loc[0])
# Out:
# str

# %%
#Convert the Datatype of the 'date' column to DateTime(Timestamp) datatype
df['date'] = pd.to_datetime(df['date'])

# %%
type(df['date'].loc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year']= df['date'].apply(lambda x:x.year)

# %%
df['month'] = df['date'].apply(lambda x:x.month)

# %%
df.shape
# Out:
# (21597, 22)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year  month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df,x='month',y='price')

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'].plot()

# %%
df = df.drop(labels=['date'],axis=1)

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df.describe().transpose()
# Out:
#                  count           mean  ...         75%           max
# price          21597.0  540296.573506  ...  645000.000  7.700000e+06
# bedrooms       21597.0       3.373200  ...       4.000  3.300000e+01
# bathrooms      21597.0       2.115826  ...       2.500  8.000000e+00
# sqft_living    21597.0    2080.321850  ...    2550.000  1.354000e+04
# sqft_lot       21597.0   15099.408760  ...   10685.000  1.651359e+06
# floors         21597.0       1.494096  ...       2.000  3.500000e+00
# waterfront     21597.0       0.007547  ...       0.000  1.000000e+00
# view           21597.0       0.234292  ...       0.000  4.000000e+00
# condition      21597.0       3.409825  ...       4.000  5.000000e+00
# grade          21597.0       7.657915  ...       8.000  1.300000e+01
# sqft_above     21597.0    1788.596842  ...    2210.000  9.410000e+03
# sqft_basement  21597.0     291.725008  ...     560.000  4.820000e+03
# yr_built       21597.0    1970.999676  ...    1997.000  2.015000e+03
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
plt.figure(figsize=(60,6))
sns.countplot(data=df,x='zipcode')

# %% [markdown]
# # Test Train Dataset Split

# %%
#Create the Dataframe for Feature Set and Target Feature set

# %%
X = df.drop(labels = ['price'],axis=1).values
y = df['price'].values

# %%
#Split the Data into Train and Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state = 101)

# %%
#Scaling of Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# # Create the Model using Keras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=19,activation='relu'))
model.add(Dense(units=1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,epochs=400,validation_data=(X_test,y_test),batch_size=128)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 3ms/step - loss: 428921487360.0000 - val_loss: 418398306304.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 427552735232.0000 - val_loss: 415170265088.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 415338561536.0000 - val_loss: 383817187328.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 344152539136.0000 - val_loss: 267870404608.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 196693442560.0000 - val_loss: 123871076352.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 114303418368.0000 - val_loss: 98046418944.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 100776042496.0000 - val_loss: 96475095040.0000
# Epoch 8/400
# ...

# %%
losses_df = pd.DataFrame(model.history.history)

# %%
losses_df.head()
# Out:
#            loss      val_loss
# 0  4.289215e+11  4.183983e+11
# 1  4.275527e+11  4.151703e+11
# 2  4.153386e+11  3.838172e+11
# 3  3.441525e+11  2.678704e+11
# 4  1.966934e+11  1.238711e+11

# %%
losses_df.plot(figsize = (15,5),grid=True)

# %% [markdown]
# # Model Evaluation

# %%
model.evaluate(x=X_test,y=y_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step - loss: 26121099264.0000
# 26121099264.0

# %%
model.evaluate(x=X_train,y=y_train)
# Out:
# 473/473 [==============================] - 0s 1ms/step - loss: 26092478464.0000
# 26092478464.0

# %%
test_pred = model.predict(X_test)

# %%
test_pred
# Out:
# array([[368360.22],
#        [589329.56],
#        [577180.56],
#        ...,
#        [380741.34],
#        [505051.16],
#        [685367.94]], dtype=float32)

# %%
test_pred_df = pd.DataFrame(data = test_pred,columns=['Predicted_Value'])

# %%
test_pred_df
# Out:
#       Predicted_Value
# 0       368360.218750
# 1       589329.562500
# 2       577180.562500
# 3       377783.406250
# 4       447478.593750
# ...               ...
# 6475    649574.375000
# 6476    213649.421875
# 6477    380741.343750
# 6478    505051.156250
# 6479    685367.937500
#
# [6480 rows x 1 columns]

# %%
actual_value_df = pd.DataFrame(data=y_test,columns=['Actual_Values'])

# %%
pred_df = pd.concat([actual_value_df,test_pred_df],axis = 1)

# %%
pred_df.head()
# Out:
#    Actual_Values  Predicted_Value
# 0       319000.0     368360.21875
# 1       464625.0     589329.56250
# 2       489950.0     577180.56250
# 3       395000.0     377783.40625
# 4       458000.0     447478.59375

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(data=pred_df,x='Actual_Values',y='Predicted_Value')
plt.plot(y_test,y_test,'r')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
mean_absolute_error(y_true=pred_df['Actual_Values'],y_pred=pred_df['Predicted_Value'])
# Out:
# 100215.04732470101

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_true=pred_df['Actual_Values'],y_pred=pred_df['Predicted_Value'])
# Out:
# 0.8031219843323695

# %% [markdown]
# # Predict Price of New House on Sale

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# zipcode           98178.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# year               2014.0000
# month                10.0000
# Name: 0, dtype: float64

# %%
single_house = df.drop(labels=['price'],axis=1).iloc[0].values

# %%
single_house
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  9.81780e+04,  4.75112e+01, -1.22257e+02,
#         1.34000e+03,  5.65000e+03,  2.01400e+03,  1.00000e+01])

# %%
single_house.shape
# Out:
# (20,)

# %%
single_house = single_house.reshape(-1,20)

# %%
single_house
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  9.81780e+04,  4.75112e+01, -1.22257e+02,
#          1.34000e+03,  5.65000e+03,  2.01400e+03,  1.00000e+01]])

# %%
scaler.transform(single_house)
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.89393939, 0.57149751,
#         0.21760797, 0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
single_house = scaler.transform(single_house)

# %%
model.predict(single_house)
# Out:
# array([[268967.06]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3        1.0  ...        5650  2014     10
#
# [1 rows x 21 columns]

# %%
#Predicted Value is 268967.06
#Actual Value is 221900
